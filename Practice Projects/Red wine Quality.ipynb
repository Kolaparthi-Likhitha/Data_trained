# %% [markdown]
# ###### Importing the dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Dell\Documents/redwine.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# fixed acidity: most acids involved with wine or fixed or nonvolatile
# volatile acidity: the amount of acetic acid in wine
# citric acid: found in small quantities, citric acid can add 'freshness' and flavor to wines
# residual sugar: the amount of sugar remaining after fermentation stops chlorides: the amount of salt in the wine
# free sulfur dioxide: the free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion total sulfur dioxide: amount of free and bound forms of S02
# density: the density of water is close to that of water depending on the percent alcohol and sugar content
# pH: describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic) as per ph range
# sulphates: a wine additive which can contribute to sulfur dioxide gas (S02) levels
# alcohol: the percent alcohol content of the wine
# quality: output variable (based on sensory data, score between 0 and 10)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# Average value of fixed acidity is 8.31 and the maximum value is 15.9 Average value of volatile acidity is 0.52 and the maximum value is 1.58 Average value of citric acid is 0.27 and the maximum value is 1.0 Average value of residual sugar is 2.53 and the maximum value is 15.5 Average value of chlorides is 0.08 and the maximum value is 0.61 Average value of free sulfur dioxide is 15.87 and the maximum value is 72.0 Average value of total sulfur dioxide is 46.46 and the maximum value is 289.0 Average value of density is 0.99 and the maximum value is 1.0 Average value of pH is 3.31 and the maximum value is 4.01 Average value of sulphates is 0.65 and the maximum value is 2.0 Average value of quality is 5.63 and the maximum value is 8.0

# %% [markdown]
# Checking if any null values are present

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Hence there is no null data

# %% [markdown]
# ###### EDA - Data Analysis

# %%
import seaborn as sns  #for data visualization
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# By analyzing the graphs, we find fixed acidity are relatively normally distributed but a bit skewed. There are two peaks in the distributions of other volatile acidity and citric acid variables. In chlorides,residual sugar,free sulfur dioxide,total sulfur dioxide the data is completely right skewed In sulphates the data is bit right skewed and in alcohol there are two peaks in the distribution.

# %%
plt.figure()
sns.pairplot(df,hue = 'quality', palette = "Set1")
plt.show()

# %%
plt.figure(figsize = [20, 10])
sns.heatmap(df.corr(), annot = True, linewidths = 2)
plt.show()

# %% [markdown]
# From pairplot and correlation map, we see that there is correlation between some variables. we also see that there is relatively high 0.67 correlation between free sulfur dioxide and total_sulfur_dioxide There is relatively high -0.68 correlation between pH and fixed_acidity variables. There is correlation between some of other variables. That is called multicollinearity. we need to avoid that problem.

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# ###### Data Processing

# %% [markdown]
# ###### Analysing target variable
#
# - In this dataset quality range is between 3 and 8
# - We will divide quality range into two parts:
# - good - 7 or greater than 7
# - not good - less than 7
# - performing data binning to classify and categorize the data

# %%
df['quality']=df.quality.apply(lambda x:1 if x>=7 else 0)

# %%
df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %% [markdown]
# - performing feature selection methods
# - Here we are using 'univariate selection method' to select the features that have strongest relationship with target variable

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from pandas import DataFrame

# %%
X=df.drop('quality',axis=1)
y=df.quality

# %%
bestfeatures=SelectKBest(score_func=chi2,k=7)  # finding 7 best features
fit=bestfeatures.fit(X,y)

# %%
df_scores=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(X.columns)

# %% [markdown]
# - concatenating data frames

# %%
feature_scores=pd.concat([df_columns,df_scores],axis=1)
feature_scores.columns=['Feature_name','Score']

# %%
feature_scores
# Out:
#             Feature_name       Score
# 0          fixed acidity    8.393096
# 1       volatile acidity    7.113769
# 2            citric acid   10.317077
# 3         residual sugar    2.856369
# 4              chlorides    0.383204
# 5    free sulfur dioxide   56.696032
# 6   total sulfur dioxide  724.343506
# 7                density    0.000129
# 8                     pH    0.037747
# 9              sulphates    2.776190
# 10               alcohol   28.886089

# %%
print(feature_scores.nlargest(7,'Score'))
# Out:
#             Feature_name       Score
# 6   total sulfur dioxide  724.343506
# 5    free sulfur dioxide   56.696032
# 10               alcohol   28.886089
# 2            citric acid   10.317077
# 0          fixed acidity    8.393096
# 1       volatile acidity    7.113769
# 3         residual sugar    2.856369

# %% [markdown]
# - checking if outliers are present in the data by using box plot

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# we observe that there are outliers in each feature.
# There are less no of outliers in citric acid and alcohol

# %% [markdown]
# ###### Building model with the top 7 features

# %%
new_X=df[['total sulfur dioxide','free sulfur dioxide','alcohol','citric acid','fixed acidity','volatile acidity','residual sugar']]

# %%
new_X.head()
# Out:
#    total sulfur dioxide  free sulfur dioxide  alcohol  citric acid  \
# 0                  34.0                 11.0      9.4         0.00
# 1                  67.0                 25.0      9.8         0.00
# 2                  54.0                 15.0      9.8         0.04
# 3                  60.0                 17.0      9.8         0.56
# 4                  34.0                 11.0      9.4         0.00
#
#    fixed acidity  volatile acidity  residual sugar
# 0            7.4              0.70             1.9
# 1            7.8              0.88             2.6
# 2            7.8              0.76             2.3
# 3           11.2              0.28             1.9
# 4            7.4              0.70             1.9

# %%
new_X.shape
# Out:
# (1599, 7)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_X, y, test_size = 0.2, random_state = 42)  
#here trained the model with only 7(new_X) features

# %% [markdown]
# ###### Classification Models

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# write one function and call as many times as to check accuracy_score for different models

# classify function
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score
def metric_score(clf,X_train,X_test,y_train,y_test,train=True):
    
    if train:
        y_pred=clf.predict(X_train)
        print('--Train Result--')
        print(f'Accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%')
    
    elif train==False:
        y_pred=clf.predict(X_test)
        print('--Test Result--')
        print(f'Accuracy score:{accuracy_score(y_test,y_pred)*100:.2f}%')
        
    #cross-validation
    score = cross_val_score(clf, new_X, y, cv=5)
    print("CV Score:", np.mean(score)*100)

# %% [markdown]
# ###### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
metric_score(lr,X_train,X_test,y_train,y_test,train=True) #for training score
metric_score(lr,X_train,X_test,y_train,y_test,train=False) #for testing score
# Out:
# --Train Result--
# Accuracy score:87.57%
# CV Score: 86.24177115987462
# --Test Result--
# Accuracy score:84.38%
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# ###### Knn model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
metric_score(knn,X_train,X_test,y_train,y_test,train=True) #for training score
metric_score(knn,X_train,X_test,y_train,y_test,train=False) #for testing score
# Out:
# --Train Result--
# Accuracy score:89.91%
# CV Score: 84.55485893416927
# --Test Result--
# Accuracy score:88.12%
# CV Score: 84.55485893416927

# %% [markdown]
# ###### Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt= DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
metric_score(dt,X_train,X_test,y_train,y_test,train=True) #for training score
metric_score(dt,X_train,X_test,y_train,y_test,train=False) #for testing score
# Out:
# --Train Result--
# Accuracy score:100.00%
# CV Score: 80.23530564263324
# --Test Result--
# Accuracy score:84.06%
# CV Score: 81.54976489028213

# %% [markdown]
# ###### RandomForest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
metric_score(rf,X_train,X_test,y_train,y_test,train=True) #for training score
metric_score(rf,X_train,X_test,y_train,y_test,train=False) #for testing score
# Out:
# --Train Result--
# Accuracy score:99.92%
# CV Score: 85.61657523510972
# --Test Result--
# Accuracy score:90.00%
# CV Score: 85.36637931034483

# %% [markdown]
# ###### support vector machine model

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(X_train,y_train)
# Out:
# SVC()

# %%
metric_score(sv,X_train,X_test,y_train,y_test,train=True) #for training score
metric_score(sv,X_train,X_test,y_train,y_test,train=False) #for testing score
# Out:
# --Train Result--
# Accuracy score:89.29%
# CV Score: 86.4290752351097
# --Test Result--
# Accuracy score:86.25%
# CV Score: 86.4290752351097

# %% [markdown]
# By training the models, the testing accuracy score is highest in Random Forest model. So, we choose that model as the best fit model.

# %% [markdown]
# ###### ROC curve

# %%
pred_prob1=lr.predict_proba(X_test)
pred_prob2=knn.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve
fpr1,tpr1,thresh1=roc_curve(y_test,pred_prob1[:,1],pos_label=1)
fpr2,tpr2,thresh2=roc_curve(y_test,pred_prob2[:,1],pos_label=1)
random_probs=[0 for i in range(len(y_test))]
p_fpr,p_tpr,_=roc_curve(y_test,random_probs,pos_label=1)

# %%
from sklearn.metrics import roc_auc_score
auc_score1=roc_auc_score(y_test,pred_prob1[:,1])
auc_score2=roc_auc_score(y_test,pred_prob2[:,1])
print(auc_score1,auc_score2)
# Out:
# 0.867664250642974 0.8512197022835322

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

plt.plot(fpr1,tpr1,linestyle='--',color='red',label='LogisticRegression')
plt.plot(fpr2,tpr2,linestyle='--',color='green',label='KNN')
plt.plot(p_fpr,p_tpr,linestyle='--',color='blue')

plt.title("ROC curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show()

# %% [markdown]
# It is evident from the plot that AUC for Logistic Regression curve is bit higher than that for the KNN ROC curve. Therefore we say that logistic regression did a better job of classifying the quality of redwine in the dataset.
