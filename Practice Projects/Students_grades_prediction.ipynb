# %% [markdown]
# #  GRADES OF STUDENTS PREDICTION

# %% [markdown]
# ### Importing the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Dell\Documents\grades.csv')

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (571, 43)

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# - Since all the columns are in strings converting them to numerical data using label encoder

# %%
df1=df.copy()

# %%
df2=df[['Seat No.','CGPA']]

# %%
from sklearn import preprocessing
lab_enc=preprocessing.LabelEncoder()

# %%
#Dropping the unrequired columns
df = df.drop(['CGPA','Seat No.'], axis = 1)

# %%
#Applying label encoder to the dataset
for i in df.columns:
    df[i] = lab_enc.fit_transform(df[i].astype(str))

# %%
df.head(100)
# Out:
#     PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0        5      10       8          6       8      10       9       8       5
# 1        0       9      10          9       5       6       9       0      10
# 2        0       3       0          5       4       0       5       4       2
# 3        9       7      10          9       9       2      10       8       9
# 4        2       2       2          4       0       0       2       4       0
# ..     ...     ...     ...        ...     ...     ...     ...     ...     ...
# 95       0       5       1          2       0       1       0       0       0
# 96       0       3       1          3       0       1       0       0       0
# 97       0       5       0          2       5       2       5       2       2
# 98       0       4       1          0       1       0       2       0       0
# 99       7       6       2          5       5       8       9       5       7
#
# ...

# %%
df_f=pd.concat([df,df2],axis=1) #appending the seat no. column and CGPA column

# %%
df_f.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       5      10       8          6       8      10       9       8       5
# 1       0       9      10          9       5       6       9       0      10
# 2       0       3       0          5       4       0       5       4       2
# 3       9       7      10          9       9       2      10       8       9
# 4       2       2       2          4       0       0       2       4       0
#
#    ME-107  ...  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  CS-423  \
# 0       8  ...       8       8       8       2       0       8       3
# 1       9  ...       9       6       9       2       5       6       6
# 2       2  ...       3       0       6       0       0       0       2
# 3       7  ...       6      10       8       5       3       7       7
# 4       2  ...       4       4       5       2       0       2       2
#
#    CS-412  Seat No.   CGPA
# 0       2  CS-97001  2.205
# ...

# %%
df_f.isnull().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# Seat No.     0
# CGPA         0
# dtype: int64

# %% [markdown]
# - There is no null data in any of the columns

# %% [markdown]
# ### Dataframe Description

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int32
#  1   HS-101     571 non-null    int32
#  2   CY-105     571 non-null    int32
#  3   HS-105/12  571 non-null    int32
#  4   MT-111     571 non-null    int32
#  5   CS-105     571 non-null    int32
#  6   CS-106     571 non-null    int32
#  7   EL-102     571 non-null    int32
#  8   EE-119     571 non-null    int32
#  9   ME-107     571 non-null    int32
#  10  CS-107     571 non-null    int32
#  11  HS-205/20  571 non-null    int32
#  12  MT-222     571 non-null    int32
#  13  EE-222     571 non-null    int32
#  14  MT-224     571 non-null    int32
#  15  CS-210     571 non-null    int32
#  16  CS-211     571 non-null    int32
#  17  CS-203     571 non-null    int32
#  18  CS-214     571 non-null    int32
#  19  EE-217     571 non-null    int32
# ...

# %%
df_f.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.781086    5.071804    2.921191    4.264448    3.935201    2.838879
# std      3.046895    2.785317    2.992228    3.216478    3.034481    2.696709
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    5.000000    7.000000    6.000000    4.000000
# max     12.000000   11.000000   13.000000   13.000000   13.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.161121    3.998249    3.921191    4.817863  ...    4.299475
# ...

# %% [markdown]
# - Average CGPA is 295, min CGPA is 0.80, max CGPA is 3.985

# %% [markdown]
# ### Column wise memory usage

# %%
df_f.memory_usage()
# Out:
# Index         128
# PH-121       2284
# HS-101       2284
# CY-105       2284
# HS-105/12    2284
# MT-111       2284
# CS-105       2284
# CS-106       2284
# EL-102       2284
# EE-119       2284
# ME-107       2284
# CS-107       2284
# HS-205/20    2284
# MT-222       2284
# EE-222       2284
# MT-224       2284
# CS-210       2284
# CS-211       2284
# CS-203       2284
# CS-214       2284
# EE-217       2284
# CS-212       2284
# CS-215       2284
# MT-331       2284
# EF-303       2284
# HS-304       2284
# CS-301       2284
# CS-302       2284
# TC-383       2284
# MT-442       2284
# EL-332       2284
# CS-318       2284
# CS-306       2284
# CS-312       2284
# CS-317       2284
# CS-403       2284
# CS-421       2284
# CS-406       2284
# CS-414       2284
# CS-419       2284
# CS-423       2284
# CS-412       2284
# Seat No.     4568
# CGPA         4568
# dtype: int64

# %% [markdown]
# #### Numerical and Categorical Columns

# %%
num_col=[col for col in df_f.columns if df_f[col].dtypes!='O']
print('We have {} numerical features: {}'.format(len(num_col),num_col))
# Out:
# We have 42 numerical features: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA']

# %%
cat_col=[col for col in df_f.columns if df_f[col].dtypes=='O']
print('We have {} categorical features: {}'.format(len(cat_col),cat_col))
# Out:
# We have 1 categorical features: ['Seat No.']

# %% [markdown]
# ### Univariate Analysis

# %%
df_f.var()
# Out:
# PH-121        9.283571
# HS-101        7.757993
# CY-105        8.953427
# HS-105/12    10.345734
# MT-111        9.208074
# CS-105        7.272240
# CS-106        7.696802
# EL-102        9.461400
# EE-119        7.279743
# ME-107       10.107119
# CS-107       10.917787
# HS-205/20     6.396590
# MT-222       11.576176
# EE-222        9.897066
# MT-224       10.578400
# CS-210        8.783820
# CS-211       10.817532
# CS-203       10.060927
# CS-214        9.633564
# EE-217        8.192767
# CS-212        8.215848
# CS-215       10.349359
# MT-331       10.444938
# EF-303        6.999158
# HS-304        8.493649
# CS-301        9.021649
# CS-302        7.185529
# TC-383       10.929167
# MT-442        9.036059
# EL-332        9.618570
# CS-318        9.909288
# CS-306        9.300292
# CS-312       12.817175
# CS-317        8.568114
# CS-403        9.788490
# CS-421        8.504470
# CS-406       20.847273
# CS-414        8.591870
# CS-419        7.059588
# CS-423        9.244490
# ...

# %% [markdown]
# ##### Numerical Features

# %%
#Visualizing how the CGPA is distributed.

f,ax = plt.subplots(1,1, figsize=(12,8))
ax = sns.distplot(df_f['CGPA'], kde = True, color = 'c')
plt.title('Distribution of CGPA')
# Out:
# Text(0.5, 1.0, 'Distribution of CGPA')

# %%
#finding how much is skewed

from scipy import stats
cgpa_log=np.log(df_f['CGPA']) 
cgpa_log.skew()
# Out:
# -1.2388153176206902

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 8))
ax = sns.distplot(np.log(df_f['CGPA']), kde = True, color = 'r' )

# %%
plt.figure(figsize=(10,15))
plt.suptitle('Univariate Analysis',fontsize=15,fontweight='bold')

for i in range(0,len(num_col)):
    plt.subplot(11,4,i+1)
    sns.kdeplot(x=df_f[num_col[i]],shade=True,color='b')
    plt.xlabel(num_col[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(10,15))
plt.suptitle('Scatter plot for numerical features',fontsize=15,fontweight='bold')

for i in range(0,len(num_col)):
    plt.subplot(11,4,i+1)
    sns.scatterplot(y=num_col[i],x=df_f.index,data=df_f,color='b')
    plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.lmplot(x = 'PH-121', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'HS-101', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CY-105', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'HS-105/12', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'MT-111', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-105', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-106', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EL-102', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EE-119', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'ME-107', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-107', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'HS-205/20', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'MT-222', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EE-222', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'MT-224', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-210', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-211', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-203', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-214', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EE-217', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-212', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-215', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'MT-331', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EF-303', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'HS-304', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-301', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-302', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'TC-383', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'MT-442', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'EL-332', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-318', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-306', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-312', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-317', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-403', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-421', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-406', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-414', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-419', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-423', y = 'CGPA', data=df_f)

# %%
sns.lmplot(x = 'CS-412', y = 'CGPA', data=df_f)

# %% [markdown]
# ##### Correlation between different variables

# %%
df_f.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.565773   0.508231  0.487830  0.609990
# HS-101     0.382436  1.000000  0.334536   0.473146  0.441847  0.400713
# CY-105     0.565773  0.334536  1.000000   0.516758  0.554936  0.587845
# HS-105/12  0.508231  0.473146  0.516758   1.000000  0.505049  0.493581
# MT-111     0.487830  0.441847  0.554936   0.505049  1.000000  0.416784
# CS-105     0.609990  0.400713  0.587845   0.493581  0.416784  1.000000
# CS-106     0.319649  0.321346  0.404763   0.516214  0.528063  0.310666
# EL-102     0.443420  0.359801  0.466034   0.373136  0.568940  0.377496
# EE-119     0.589250  0.323381  0.501859   0.425518  0.422151  0.522205
# ME-107     0.548820  0.345819  0.485183   0.334125  0.478874  0.464978
# CS-107     0.501814  0.507674  0.501331   0.550732  0.503985  0.530578
# HS-205/20  0.338530  0.200494  0.325533   0.224536  0.372303  0.229860
# ...

# %% [markdown]
# #### Heatmap for multicollinearity

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df_f.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Boxplot for Outliers

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=df_f,orient='v')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - From the above boxplots, we find that there are maximum number of outliers in the columns 'HS-205/20', 'CS-210','EE-217','CS-302','CS-414','CS-419'

# %% [markdown]
# ##### Treating the outliers

# %%
#Creating a function to drop the outliers

def drop_outliers(df,col_name):
    iqr=1.5+(np.percentile(df[col_name],75)-np.percentile(df[col_name],25))
    df.drop(df[df[col_name]>(iqr+np.percentile(df[col_name],75))].index,inplace=True)
    df.drop(df[df[col_name]<(np.percentile(df[col_name],25)-iqr)].index,inplace=True)

# %%
drop_outliers(df_f,'HS-205/20')

# %%
sns.boxplot(df_f['HS-205/20'])
plt.title('after removing outliers')
plt.show()

# %%
drop_outliers(df_f,'CS-210')

# %%
sns.boxplot(df_f['CS-210'])
plt.title('after removing outliers')
plt.show()

# %%
drop_outliers(df_f,'EE-217')

# %%
sns.boxplot(df_f['EE-217'])
plt.title('after removing outliers')
plt.show()

# %%
drop_outliers(df_f,'CS-302')

# %%
sns.boxplot(df_f['CS-302'])
plt.title('after removing outliers')
plt.show()

# %%
drop_outliers(df_f,'CS-414')

# %%
sns.boxplot(df_f['CS-414'])
plt.title('after removing outliers')
plt.show()

# %%
drop_outliers(df_f,'CS-419')

# %%
sns.boxplot(df_f['CS-419'])
plt.title('after removing outliers')
plt.show()

# %% [markdown]
# - Outliers are removed from the columns

# %% [markdown]
# #### Building the models

# %%
x = df_f.drop(['CGPA','Seat No.'], axis = 1)
y = df_f['CGPA']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# ### #LINEAR REGRESSION

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, r2_score,accuracy_score
lr= LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

# Scores:
print("Model training score:",lr.score(x_train,y_train)*100,'%')
print('Model Testing Score:',lr.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Model training score: 98.98533471138012 %
# Model Testing Score: 98.34758250387618 %
# R2 Score: 0.9834758250387619
# MSE: 0.0034560069955256296
# RMSE:  0.0587878133249199

# %% [markdown]
# ### #RANDOM FOREST REGRESSOR

# %%
#RANDOM FOREST REGRESSOR
 
from sklearn.ensemble import RandomForestRegressor
rfr= RandomForestRegressor()
rfr.fit(x_train, y_train)
y_pred = rfr.predict(x_test)

# Scores:
print("Model training score:",rfr.score(x_train,y_train)*100,'%')
print('Model Testing Score:',rfr.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Model training score: 99.16973705364146 %
# Model Testing Score: 94.72579273523122 %
# R2 Score: 0.9472579273523123
# MSE: 0.011030927259999929
# RMSE:  0.10502822125505092

# %% [markdown]
# ### #K NEIGHBOR REGRESSOR

# %%
#K NEIGHBOR REGRESSOR
from sklearn.neighbors import KNeighborsRegressor
KNN= KNeighborsRegressor()
KNN.fit(x_train, y_train)
y_pred = KNN.predict(x_test)

# Scores:
print("Model training score:",KNN.score(x_train,y_train)*100,'%')
print('Model Testing Score:',KNN.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Model training score: 96.82937146506232 %
# Model Testing Score: 95.310332679554 %
# R2 Score: 0.95310332679554
# MSE: 0.009808370526315802
# RMSE:  0.09903721788457005

# %% [markdown]
# ### #RIDGE REGRESSION

# %%
#RIDGE REGRESSION
from sklearn.linear_model import Ridge
ri=Ridge()
ri.fit(x_train, y_train)
y_pred = ri.predict(x_test)

# Scores:
print("Model training score:",ri.score(x_train,y_train)*100,'%')
print('Model Testing Score:',ri.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
# Out:
# Model training score: 98.9853097960635 %
# Model Testing Score: 98.35657334401981 %
# R2 Score: 0.983565733440198
# MSE: 0.0034372027850250258

# %% [markdown]
# ### #DECISION TREE REGRESSOR

# %%
#DECISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=1)
dtr.fit(x_train, y_train)
y_pred = dtr.predict(x_test)

# Scores:
print("Model training score:",dtr.score(x_train,y_train)*100,'%')
print('Model Testing Score:',dtr.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Model training score: 100.0 %
# Model Testing Score: 78.3012182823635 %
# R2 Score: 0.7830121828236349
# MSE: 0.045382684210526304
# RMSE:  0.21303212013808223

# %% [markdown]
# #### Determining Feature Importance values

# %%
importances = dtr.feature_importances_

# Sort the feature importance in descending order
#
sorted_indices = np.argsort(importances)[::-1]
 
feat_labels = df_f.columns[1:]
 
for f in range(x_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30,
                            feat_labels[sorted_indices[f]],
                            importances[sorted_indices[f]]))
# Out:
#  1) CS-403                         0.534577
#  2) CS-105                         0.106179
#  3) EE-217                         0.099584
#  4) MT-331                         0.056271
#  5) EE-222                         0.026891
#  6) EL-332                         0.024745
#  7) CS-203                         0.018469
#  8) CS-318                         0.014810
#  9) EE-119                         0.014576
# 10) CS-406                         0.013888
# 11) CS-212                         0.011509
# 12) EL-102                         0.007857
# 13) CS-421                         0.007467
# 14) MT-442                         0.007103
# 15) HS-105/12                      0.005319
# 16) CS-312                         0.004015
# 17) CS-211                         0.003925
# 18) HS-205/20                      0.003723
# 19) TC-383                         0.003687
# 20) Seat No.                       0.003562
# 21) CS-414                         0.003186
# ...

# %% [markdown]
# ### #SUPPORT VECTOR REGRESSOR

# %%
#SUPPORT VECTOR REGRESSOR
from sklearn.svm import SVR
svr= SVR()
svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

# Scores:
print("Model training score:",svr.score(x_train,y_train)*100,'%')
print('Model Testing Score:',svr.score(x_test, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Model training score: 98.236220548019 %
# Model Testing Score: 96.14565722080246 %
# R2 Score: 0.9614565722080246
# MSE: 0.008061301480592841
# RMSE:  0.08978475082436238

# %% [markdown]
# - As we have more features i.e., 43 columns. So, I have used dimensionality reduction algorithm 'Principal Component Analysis(PCA)' to solve this issue.

# %% [markdown]
# ##### Applying PCA

# %%
from sklearn.decomposition import PCA
pca=PCA()
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)

# %%
explained_variance=pca.explained_variance_ratio_

# %%
explained_variance
# Out:
# array([0.38947233, 0.10574481, 0.05157397, 0.04590039, 0.02743921,
#        0.02416438, 0.02251338, 0.02048815, 0.01865228, 0.01699694,
#        0.01662117, 0.01567105, 0.01521369, 0.01382823, 0.01286351,
#        0.01209639, 0.0119082 , 0.01130692, 0.01102331, 0.01069162,
#        0.01016716, 0.00983954, 0.00945586, 0.00890774, 0.00858025,
#        0.00828505, 0.00791674, 0.00771457, 0.00761142, 0.00712244,
#        0.00683039, 0.00658602, 0.00631697, 0.00609996, 0.00575798,
#        0.00540488, 0.00522942, 0.0050853 , 0.00473296, 0.00446448,
#        0.00372093])

# %% [markdown]
# - It can be seen that first principal component is responsible for 48% variance. Similarly first 21 components are collectively having 85.3% in the feature set.
# - Lets use first 21 component to train our algorithm

# %% [markdown]
# - PCA reduces dimensions by taking linear combination of different features so that we can capture maximum variance

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=21)
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)

# %% [markdown]
# #### Training the model and making predictions

# %%
#LINEAR REGRESSION
lr_p=LinearRegression()
lr_p.fit(x_train_pca,y_train)

y_pred=lr_p.predict(x_test_pca)

# %%
print('Linear Regression')
print("Model training score:",lr_p.score(x_train_pca,y_train)*100,'%')
print('Model Testing Score:',lr_p.score(x_test_pca, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Linear Regression
# Model training score: 98.83104277281738 %
# Model Testing Score: 98.72490904341487 %
# R2 Score: 0.9872490904341487
# MSE: 0.0026668340635625357
# RMSE:  0.051641398737471624

# %% [markdown]
# - After applying PCA, we find that accuracy of linear regression model has increased from 98.34% to 98.72%. There is a mild increase in the accuracy. So, PCA fit for this model.

# %%
#RANDOM FOREST REGRESSOR
from sklearn.ensemble import RandomForestRegressor
rf_p=RandomForestRegressor(max_depth=2,random_state=0)
rf_p.fit(x_train_pca,y_train)

y_pred=rf_p.predict(x_test_pca)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score,accuracy_score

print('Random Forest')
print("Model training score:",rf_p.score(x_train_pca,y_train)*100,'%')
print('Model Testing Score:',rf_p.score(x_test_pca, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Random Forest
# Model training score: 94.57815766065755 %
# Model Testing Score: 92.41953674334513 %
# R2 Score: 0.9241953674334513
# MSE: 0.015854427894753595
# RMSE:  0.12591436730871342

# %% [markdown]
# - After applying PCA, we find that accuracy of random forest model has reduced from 94.72% to 92.41%. So, PCA doesnt fit for this model.

# %%
#K NEIGHBOR REGRESSOR
knn_p=KNeighborsRegressor()
knn_p.fit(x_train_pca,y_train)

y_pred=knn_p.predict(x_test_pca)

# %%
print('K Neighbor Regressor')
print("Model training score:",knn_p.score(x_train_pca,y_train)*100,'%')
print('Model Testing Score:',knn_p.score(x_test_pca, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# K Neighbor Regressor
# Model training score: 97.59258086701308 %
# Model Testing Score: 96.25632307185367 %
# R2 Score: 0.9625632307185367
# MSE: 0.007829845473684214
# RMSE:  0.08848641406274871

# %% [markdown]
# - After applying PCA, we find that accuracy of k neighbor regression model has increased from 95.31% to 96.25%. So, PCA fit for this model.

# %%
#Decision Tree Regressor
dtr_p=DecisionTreeRegressor(random_state=1)
dtr_p.fit(x_train_pca,y_train)

y_pred=dtr_p.predict(x_test_pca)

# %%
print('Decision Tree Regressor')
print("Model training score:",dtr_p.score(x_train_pca,y_train)*100,'%')
print('Model Testing Score:',dtr_p.score(x_test_pca, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Decision Tree Regressor
# Model training score: 100.0 %
# Model Testing Score: 96.66639839165447 %
# R2 Score: 0.9666639839165446
# MSE: 0.006972178947368416
# RMSE:  0.08349957453405625

# %% [markdown]
# - After applying PCA, we find that accuracy of decision tree regression model has increased from 78.30% to 96.63%. So, PCA fit for this model.

# %%
#Ridge REGRESSOR
ri_p=Ridge()
ri_p.fit(x_train_pca,y_train)

y_pred=ri_p.predict(x_test_pca)

# %%
print('Ridge Regressor')
print("Model training score:",ri_p.score(x_train_pca,y_train)*100,'%')
print('Model Testing Score:',ri_p.score(x_test_pca, y_test)*100,'%')
print('R2 Score:',r2_score(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print("RMSE: ",mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Ridge Regressor
# Model training score: 98.83103513553041 %
# Model Testing Score: 98.72606563724452 %
# R2 Score: 0.9872606563724452
# MSE: 0.0026644150645047087
# RMSE:  0.05161797230136717

# %% [markdown]
# - After applying PCA, we find that accuracy of ridge regression model has decreased from 98.72% to 98.35% So, PCA fit for this model.

# %% [markdown]
# - We conclude that knn_p model is the best fit model as it has accuracy of 97.02%

# %%
#saving the model

import pickle
filename = 'Studentsgrades.pkl'
pickle.dump(knn_p, open(filename, 'wb'))

# %% [markdown]
# ### Conclusion

# %%
loaded_model=pickle.load(open('Studentsgrades.pkl','rb'))
result=loaded_model.score(x_test_pca,y_test)
print(result*100)
# Out:
# 96.25632307185367

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test_pca)[:],y_pred[:]],index=['Predicted','Original'])

# %%
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  3.175200  3.862800  3.258800  3.780800  3.518600  3.171800
# Original   3.129975  3.824939  3.291331  3.826464  3.473916  3.056483
#
#                  6         7         8         9   ...        85        86  \
# Predicted  2.868200  3.009200  2.703600  3.228400  ...  2.800200  3.085400
# Original   2.849864  2.937333  2.678164  3.210673  ...  2.669361  3.039262
#
#                  87        88        89        90        91        92  \
# Predicted  3.231800  3.543400  3.458200  3.781600  3.425400  3.886000
# Original   3.151287  3.414722  3.412217  3.591262  3.396262  3.884072
#
#                  93        94
# Predicted  2.758400  2.901800
# Original   2.791281  2.739144
#
# [2 rows x 95 columns]
